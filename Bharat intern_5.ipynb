# %%
#1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("C:\\Users\\SRIHARI SEKHAPURAM\Documents\Dataset .csv")

# %%
aggregate_rating = dataset['Aggregate rating']
rating_count=aggregate_rating.value_counts().sort_index()

# %%
common_rating=rating_count.idxmax()
print("Most common raring range is: ",common_rating)
# Out:
# Most common raring range is:  0.0

# %%
#2

# %%
average_votes=dataset['Votes'].mean()
print('Average number of votes recieved by restarents: ',average_votes)
# Out:
# Average number of votes recieved by restarents:  156.909747670401

# %%
plt.hist(aggregate_rating,bins=20,edgecolor='red')
plt.xlabel('Aggreagate raiting')
plt.ylabel('Frequency')
plt.title("Distribution of average rating")
plt.show()
